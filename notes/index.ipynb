# %% [markdown]
# ---
# title: "Notes"
# listing:
#   contents:
#     - "*.ipynb"
#   type: default
#   sort: date desc
#   categories: true
#   fields:
#     - title
#     - date
#     - reading-time
#     - author
#     - categories
# ---
#
# Random working drafts and low-effort notes. Newest first.
