# %% [markdown]
# ---
# title: "Notes"
# listing:
#   contents:
#     - "*.ipynb"
#   type: default
#   sort: date desc
#   fields:
#     - title
#     - date
#     - reading-time
#     - author
# ---
#
# Random working drafts and low-effort notes. Newest first.
