# %% [markdown]
# ---
# title: "001-testnote"
# date: "2026-07-25"
# categories: [test]
# ---
#
# Hello, I'm testing out Quarto docs :)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3],);

# %%
f = lambda x: 3 * x
print(f(3))
# Out:
# 9
