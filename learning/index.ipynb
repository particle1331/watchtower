# %% [markdown]
# ---
# title: "Learning"
# listing:
#   contents:
#     - "*.ipynb"
#   type: default
#   sort: date desc
#   fields:
#     - title
#     - date
#     - reading-time
#     - author
# ---
#
# Full course notes, mid-effort. Newest first.
