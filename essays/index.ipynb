# %% [markdown]
# ---
# title: "Essays"
# listing:
#   contents:
#     - "*.ipynb"
#   type: default
#   sort: date desc
#   fields:
#     - title
#     - date
#     - reading-time
#     - author
# ---
#
# Essays I've promoted from my notes. Newest first.
