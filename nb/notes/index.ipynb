# %% [markdown]
# ---
# title: "Notes"
# page-layout: full
# listing:
#   contents:
#     - "*.ipynb"
#   type: table
#   sort: date desc
#   page-size: 10
#   categories: true
#   fields:
#     - date
#     - title
#     - categories
#     - reading-time
# ---
#
# Random working drafts and low-effort notes. Newest first.
