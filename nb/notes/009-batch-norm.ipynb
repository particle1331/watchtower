# %% [markdown]
# ---
# title: "Batch Normalization"
# date: "2026-08-24"
# draft: true
# categories: [deep-learning, training, normalization]
# ---

# %% [markdown]
# Planned contents (draft stub).
#
# - The mechanism in one pass: batch statistics, learned scale and shift, running averages for eval
# - Minimal demo: small MLP trained with and without batch norm; the train/eval discrepancy made visible
# - Where batch statistics break: small batches, sequences, autoregressive models
# - Punchline: the LayerNorm lineage, companion to week 4 of the LLM course outline
#
# Referenced from the LLM course outline as background outside its inline path.
#
# Source material to steer generation: `../ai-notebooks/notebooks/deep/05-activations-and-gradients.ipynb` (and optimizer notes in `04-optimizers.ipynb` where normalization interacts with training dynamics). Reuse derivations, examples, and code where they fit; adapt notation and framing instead of copying cells wholesale.
