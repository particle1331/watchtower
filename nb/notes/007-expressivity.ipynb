# %% [markdown]
# ---
# title: "Expressivity and Universal Approximation"
# date: "2026-08-24"
# draft: true
# categories:
#   - deep-learning
#   - theory
# ---

# %% [markdown]
# Planned contents (draft stub).
#
# - Universal approximation theorem: statement, minimal proof sketch, intuition
# - What the theorem does not claim: existence is not learnability or generalization
# - Depth versus width tradeoffs
# - Why expressivity bounds matter little for modern practice, and what does
#
# Referenced from the LLM course outline as background theory outside its scope.
#
# Source material to steer generation: `../ai-notebooks/notebooks/deep/11-appendix-expressivity.ipynb`. Reuse derivations and examples where they fit; adapt notation and framing to this outline instead of copying cells wholesale.
