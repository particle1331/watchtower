# %% [markdown]
# ---
# title: "Double Descent"
# date: "2026-08-24"
# draft: true
# categories:
#   - deep-learning
#   - theory
#   - statistics
# ---

# %% [markdown]
# Planned contents (draft stub).
#
# - The classical bias-variance picture versus the modern double-descent curve
# - A minimal demonstration around the interpolation threshold
# - Model-wise versus epoch-wise double descent
# - Implications for overparameterized language models
#
# Referenced from the LLM course outline as background theory outside its scope.
#
# Source material to steer generation: `../ai-notebooks/notebooks/deep/18-appendix-double-descent.ipynb`. Reuse derivations, examples, and plots where they fit; adapt notation and framing to this outline instead of copying cells wholesale.
