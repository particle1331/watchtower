# %% [markdown]
# ---
# title: "Photos"
# ---
#
# Things that matter to me.
#
# ## Mountaineering
#
# Me and my fiancée, up in the mountains.
#
# ![](https://placehold.co/1400x800?text=photo){.lightbox}
#
# ## Philippine landscapes
#
# Photos I took back home.
#
# ![](https://placehold.co/1400x800?text=photo){.lightbox}
#
# ## The kid
#
# Dad life.
#
# ![](https://placehold.co/1400x800?text=photo){.lightbox}
