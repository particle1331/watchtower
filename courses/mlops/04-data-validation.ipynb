# %% [markdown]
# ---
# title: "Data Validation with Pandera"
# date: "2026-07-04"
# author: "Ron Medina"
# ---
#
# # # Data Validation with Pandera
#
# Defining and enforcing data contracts with Pandera.
#
# ## Topics
#
# - Schema definitions for raw datasets and training features
# - Running validation at extraction time and before training
# - Logging validation reports to MLflow
# - Schema evolution: how to handle new columns, changed types
# - Why not Great Expectations yet: when does Pandera stop being enough?
#
# ## Prerequisites
#
# MLflow tracking from [03-mlflow](03-mlflow.ipynb).
