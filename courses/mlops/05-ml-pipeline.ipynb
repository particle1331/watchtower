# %% [markdown]
# ---
# title: "ML Pipeline — Training and Packaging"
# date: "2026-07-05"
# author: "Ron Medina"
# ---
#
# # # ML Pipeline — Training and Packaging
#
# Building a reproducible scikit-learn pipeline and packaging it with MLflow.
#
# ## Topics
#
# - Feature engineering with scikit-learn Pipeline (transform + fit)
# - Training a model, logging parameters, metrics, and the fitted pipeline to MLflow
# - Registering the model and packaging preprocessing with it
# - Loading the model for inference — verifying the transforms match
# - Why this avoids training-serving skew
#
# ## Prerequisites
#
# - MLflow tracking from [03-mlflow](03-mlflow.ipynb)
# - Data validation from [04-data-validation](04-data-validation.ipynb)
