# %% [markdown]
# ---
# title: "Courses"
# listing:
#   contents:
#     - "*/index.ipynb"
#   type: grid
#   sort: false
#   fields:
#     - title
#     - description
#     - image
# ---
#
# Full course notes, mid-effort. Click a course below.
