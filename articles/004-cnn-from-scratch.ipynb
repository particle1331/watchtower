# %% [markdown]
# ---
# title: "Convolutional Networks from Scratch"
# date: "2026-08-24"
# draft: true
# categories: [deep-learning, computer-vision, architecture]
# ---

# %% [markdown]
# Planned contents (draft stub).
#
# - Convolutions and pooling implemented directly (NumPy first, then PyTorch), including shape bookkeeping
# - Locality and weight sharing as inductive biases; parameter counts versus dense layers
# - Design evolution: LeNet to VGG, receptive fields, stride and downsampling
# - Where convolutions win, and why attention displaced them for language
#
# Companion to the LLM course outline (`todos/llm-pretraining-posttraining-finetuning-course.md`), which deliberately excludes CNNs from its inline deep-learning path.
#
# Source material to steer generation: `../ai-notebooks/notebooks/deep/06-cnn.ipynb`. Reuse derivations, examples, and code where they fit; adapt notation and framing to this outline instead of copying cells wholesale.
