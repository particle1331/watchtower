# %% [markdown]
# ---
# title: "Articles"
# listing:
#   contents:
#     - "*.ipynb"
#   type: table
#   sort: date desc
#   page-size: 10
#   categories: true
#   fields:
#     - date
#     - title
#     - categories
#     - reading-time
# ---
#
# Long-form articles and deep dives. Newest first.
