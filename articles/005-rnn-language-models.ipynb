# %% [markdown]
# ---
# title: "RNN Language Models"
# date: "2026-08-24"
# draft: true
# categories: [deep-learning, nlp, architecture]
# ---

# %% [markdown]
# Planned contents (draft stub).
#
# - Vanilla RNN language model from scratch: teacher forcing, truncated BPTT
# - Vanishing and exploding gradients measured empirically across time steps
# - LSTM and GRU gates as gradient-preserving mechanisms
# - Sequence modeling before attention: encoder-decoder and the bottleneck problem
# - Why attention and transformers displaced recurrence
#
# Companion to the LLM course outline, which teaches sequence modeling through decoders only.
#
# Source material to steer generation: `../ai-notebooks/notebooks/deep/08-rnn.ipynb` and `07-language-modeling.ipynb`. Reuse derivations, examples, and code where they fit; adapt notation and framing to this outline instead of copying cells wholesale.
