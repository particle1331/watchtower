# %% [markdown]
# ---
# title: "Batch Normalization"
# date: "2026-08-24"
# draft: true
# categories: [deep-learning, training, normalization]
# ---

# %% [markdown]
# Planned contents (draft stub).
#
# - Internal covariate shift: the original motivation and later critiques
# - Batch statistics, running averages, and the train/eval discrepancy
# - Interactions with learning rate, weight decay, and regularization
# - Where batch normalization breaks: small batches, sequences, autoregressive models
# - The LayerNorm lineage; companion to week 4 of the LLM course outline
#
# Source material to steer generation: `../ai-notebooks/notebooks/deep/05-activations-and-gradients.ipynb` (and optimizer notes in `04-optimizers.ipynb` where normalization interacts with training dynamics). Reuse derivations, examples, and code where they fit; adapt notation and framing to this outline instead of copying cells wholesale.
