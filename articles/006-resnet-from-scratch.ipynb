# %% [markdown]
# ---
# title: "ResNet from Scratch"
# date: "2026-08-24"
# draft: true
# categories: [deep-learning, computer-vision, architecture]
# ---

# %% [markdown]
# Planned contents (draft stub).
#
# - The degradation problem: deeper plain networks underfit, not overfit
# - Residual learning: F(x) + x and identity shortcuts
# - BasicBlock and bottleneck implementations; training at CIFAR scale
# - Why residuals ease optimization (the gradient highway)
# - Connection to transformer residual streams in the LLM course, week 4
#
# Source material to steer generation: `../ai-notebooks/notebooks/deep/12-appendix-resnet.ipynb`. Reuse derivations, examples, and code where they fit; adapt notation and framing to this outline instead of copying cells wholesale.
